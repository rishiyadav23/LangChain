# %% [markdown]
# - Get setup with langchain, langsmith, langserve
# - Basic and common components of langchain: prompt templates, models and output parrsers
# - Build Simple app
# - Trace app with langsmith
# - Serve app with langserve

# %% [markdown]
# ### BASIC COMPONENTS AND MODULES IN LANGCHAIN
# - RAG
#     - Module 1
#         - Data Ingestion (Most Imp Component)
#         - Data Sources -> Data Transformation -> Embedding -> Data Store
#         - Load -> Split (Data into chunks) -> Embed (Text into Vectors) -> Store it into VectorStore DB (FAISS, CHROMA DB, ASTRA DB)
#
#         ![image.png](attachment:image.png)
#     - Module 2
#
#         ![image-2.png](attachment:image-2.png)
#
#         - Retrieval Chain
#             - Interface for query vector store db
#         - Prompt
#             - Once we get context info, we combine it with Prompt and pass it to LLM model to get o/p response
